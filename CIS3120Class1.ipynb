# %% [markdown]
# <a href="https://colab.research.google.com/github/TahHos06/AESGCM-Encryptor/blob/main/CIS3120Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # My Hello World Program now works.
